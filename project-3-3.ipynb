# %%
import pandas as pd
import requests

API_URL = "https://data-charts-api.hexlet.app"

# %%
visits_resp = requests.get(f"{API_URL}/visits", params={"begin": "2023-03-01", "end": "2023-09-01"})
visits = pd.DataFrame(visits_resp.json())

regs_resp = requests.get(f"{API_URL}/registrations", params={"begin": "2023-03-01", "end": "2023-09-01"})
regs = pd.DataFrame(regs_resp.json())
